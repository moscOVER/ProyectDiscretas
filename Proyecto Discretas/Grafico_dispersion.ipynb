# %% [markdown]
# Gráfica dispersión: Edad y Colesterol

# %%
import pandas as pd
import matplotlib.pyplot as plt

pacientes = pd.read_csv('pacientes.csv')

saludables = pacientes[pacientes['problema_cardiaco'] == 0]
cardiacos = pacientes[pacientes['problema_cardiaco'] == 1]

plt.figure(figsize=(6, 6)) # Tamaño de la figura, posible ajuste
plt.xlabel('Edad', fontsize= 20.0) # Etiqueta eje x
plt.ylabel('Colesterol', fontsize= 20.0) # Etiqueta eje y
plt.scatter(saludables["edad"], saludables["colesterol"], label="Saludable (Clase: 0)",marker="*",c="blue",s=200)
plt.scatter(cardiacos["edad"], cardiacos["colesterol"], label="Cardiaco (Clase: 1)",marker="*",c="red",s=200) 
plt.legend(bbox_to_anchor=(1, 0.15))
plt.show()
